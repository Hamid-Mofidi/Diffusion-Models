# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamid-Mofidi/Diffusion-Models/blob/main/GMM_noising/synthetic0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import matplotlib

# %%
n_samples = 10000
n_features = 1
centers = np.array([[1.,1.1,2.,2.2]]).T
cluster_std = [0.5,0.5,0.3,0.4]
random_seed = 42

# %%
X, y = make_blobs(n_samples=n_samples,
                  n_features=n_features,
                  centers=centers,
                  cluster_std=cluster_std,
                  random_state=random_seed)

# %%
for label in np.unique(y):
    idx = np.where(y==label)
    x_idx = X[idx]
    plt.hist(x_idx,alpha=0.2)
plt.grid('both')
plt.show()

# %%
diffusion_steps = 20
eps = 1e-2

X_noised = X

for _ in range(diffusion_steps):
    noise = np.random.normal(size=X.shape)
    X_noised = X_noised + eps*noise

for label in np.unique(y):
    idx = np.where(y==label)
    x_idx = X_noised[idx]
    plt.hist(x_idx,alpha=0.2)
plt.grid('both')
plt.show()

# %%
diffusion_steps = 500
eps = 1e-2

X_noised = X

for _ in range(diffusion_steps):
    noise = np.random.normal(size=X.shape)
    X_noised = X_noised + eps*noise

for label in np.unique(y):
    idx = np.where(y==label)
    x_idx = X_noised[idx]
    plt.hist(x_idx,alpha=0.2)
plt.grid('both')
plt.show()

# %%
diffusion_steps = 2000
eps = 1e-2

X_noised = X

for _ in range(diffusion_steps):
    noise = np.random.normal(size=X.shape)
    X_noised = X_noised + eps*noise

for label in np.unique(y):
    idx = np.where(y==label)
    x_idx = X_noised[idx]
    plt.hist(x_idx,alpha=0.2)
plt.grid('both')
plt.show()

# %%
diffusion_steps = 20000
eps = 1e-2

X_noised = X

for _ in range(diffusion_steps):
    noise = np.random.normal(size=X.shape)
    X_noised = X_noised + eps*noise

for label in np.unique(y):
    idx = np.where(y==label)
    x_idx = X_noised[idx]
    plt.hist(x_idx,alpha=0.2)
plt.grid('both')
plt.show()

# %%
diffusion_steps = 200000
eps = 1e-2

X_noised = X

for _ in range(diffusion_steps):
    noise = np.random.normal(size=X.shape)
    X_noised = X_noised + eps*noise

for label in np.unique(y):
    idx = np.where(y==label)
    x_idx = X_noised[idx]
    plt.hist(x_idx,alpha=0.2)
plt.grid('both')
plt.show()
